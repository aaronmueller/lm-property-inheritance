# %%
import torch
import os

from collections import defaultdict
os.environ['TRANSFORMERS_CACHE'] = "/home/shared/km_cache"
from minicons import cwe
from semantic_memory import vsm

from transformers import AutoTokenizer
# Out:
# /home/km55359/.conda/envs/kmisra/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
lm = cwe.CWE("mistralai/Mistral-7B-Instruct-v0.2", "cuda:0")
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
lm.model.num_parameters()
# Out:
# 7110664192

# %%
vocab, embs = torch.load("/home/km55359/mistral_Mistral-7B-Instruct-v0.2.emb")

# %%
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2", cache_dir="/home/shared/km_cache")

# %%
tokenizer.convert_ids_to_tokens(tokenizer("I had a tiger.")['input_ids'])
# Out:
# ['<s>', '▁I', '▁had', '▁a', '▁t', 'iger', '.']

# %%
mistral = vsm.VectorSpaceModel("mistral")
mistral.load_vectors_from_tensor(embs, vocab)

# %%
mistral.neighbor(["▁animal"], 10)
# Out:
# [('▁Animal', 0.7861354351043701),
#  ('▁animals', 0.6380683183670044),
#  ('imal', 0.4117341637611389),
#  ('▁Anim', 0.3814623951911926),
#  ('Anim', 0.35900527238845825),
#  ('▁wildlife', 0.31560495495796204),
#  ('▁живо', 0.31076285243034363),
#  ('▁beast', 0.3003871440887451),
#  ('▁creature', 0.2901940941810608),
#  ('anim', 0.28736263513565063)]

# %%
vocab
# Out:
# ['<unk>',
#  '<s>',
#  '</s>',
#  '<0x00>',
#  '<0x01>',
#  '<0x02>',
#  '<0x03>',
#  '<0x04>',
#  '<0x05>',
#  '<0x06>',
#  '<0x07>',
#  '<0x08>',
#  '<0x09>',
#  '<0x0A>',
#  '<0x0B>',
#  '<0x0C>',
#  '<0x0D>',
#  '<0x0E>',
#  '<0x0F>',
#  '<0x10>',
#  '<0x11>',
#  '<0x12>',
#  '<0x13>',
#  '<0x14>',
#  '<0x15>',
#  '<0x16>',
#  '<0x17>',
#  '<0x18>',
#  '<0x19>',
#  '<0x1A>',
#  '<0x1B>',
#  '<0x1C>',
#  '<0x1D>',
#  '<0x1E>',
#  '<0x1F>',
#  '<0x20>',
#  '<0x21>',
#  '<0x22>',
#  '<0x23>',
#  '<0x24>',
#  '<0x25>',
#  '<0x26>',
#  '<0x27>',
#  '<0x28>',
#  '<0x29>',
#  '<0x2A>',
#  '<0x2B>',
#  '<0x2C>',
#  '<0x2D>',
#  '<0x2E>',
#  '<0x2F>',
#  '<0x30>',
#  '<0x31>',
#  '<0x32>',
#  '<0x33>',
#  '<0x34>',
#  '<0x35>',
#  '<0x36>',
#  '<0x37>',
#  '<0x38>',
#  '<0x39>',
#  '<0x3A>',
#  '<0x3B>',
#  '<0x3C>',
#  '<0x3D>',
#  '<0x3E>',
#  '<0x3F>',
#  '<0x40>',
#  '<0x41>',
#  '<0x42>',
#  '<0x43>',
#  '<0x44>',
#  '<0x45>',
#  '<0x46>',
#  '<0x47>',
#  '<0x48>',
#  '<0x49>',
# ...
